# %%
from wxpy import *
# 初始化机器人，扫码登陆
bot = Bot()
# 获取所有好友
my_friends = bot.friends()
print(type(my_friends))
# Out:
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# LOG OUT!
# Loading the contact, this may take a little while.
# Login successfully as 陈旭鹏
# <class 'wxpy.api.chats.chats.Chats'>

# %%
# 使用一个字典统计好友男性和女性的数量
sex_dict = {'male': 0, 'female': 0}
for friend in my_friends:
    # 统计性别
    if friend.sex == 1:
        sex_dict['male'] += 1
    elif friend.sex == 2:
        sex_dict['female'] += 1
print(sex_dict)
# Out:
# {'male': 495, 'female': 440}

# %%
province_dict
# Out:
# {'\xe4\xb8\x8a\xe6\xb5\xb7': 0,
#  '\xe4\xba\x91\xe5\x8d\x97': 0,
#  '\xe5\x86\x85\xe8\x92\x99\xe5\x8f\xa4': 0,
#  '\xe5\x8c\x97\xe4\xba\xac': 0,
#  '\xe5\x8f\xb0\xe6\xb9\xbe': 0,
#  '\xe5\x90\x89\xe6\x9e\x97': 0,
#  '\xe5\x9b\x9b\xe5\xb7\x9d': 0,
#  '\xe5\xa4\xa9\xe6\xb4\xa5': 0,
#  '\xe5\xae\x81\xe5\xa4\x8f': 0,
#  '\xe5\xae\x89\xe5\xbe\xbd': 0,
#  '\xe5\xb1\xb1\xe4\xb8\x9c': 0,
#  '\xe5\xb1\xb1\xe8\xa5\xbf': 0,
#  '\xe5\xb9\xbf\xe4\xb8\x9c': 0,
#  '\xe5\xb9\xbf\xe8\xa5\xbf': 0,
#  '\xe6\x96\xb0\xe7\x96\x86': 0,
#  '\xe6\xb1\x9f\xe8\x8b\x8f': 0,
#  '\xe6\xb1\x9f\xe8\xa5\xbf': 0,
#  '\xe6\xb2\xb3\xe5\x8c\x97': 0,
#  '\xe6\xb2\xb3\xe5\x8d\x97': 0,
#  '\xe6\xb5\x99\xe6\xb1\x9f': 0,
#  '\xe6\xb5\xb7\xe5\x8d\x97': 0,
#  '\xe6\xb9\x96\xe5\x8c\x97': 0,
#  '\xe6\xb9\x96\xe5\x8d\x97': 0,
#  '\xe6\xbe\xb3\xe9\x97\xa8': 0,
#  '\xe7\x94\x98\xe8\x82\x83': 0,
#  '\xe7\xa6\x8f\xe5\xbb\xba': 0,
#  '\xe8\xa5\xbf\xe8\x97\x8f': 0,
#  '\xe8\xb4\xb5\xe5\xb7\x9e': 0,
#  '\xe8\xbe\xbd\xe5\xae\x81': 0,
#  '\xe9\x87\x8d\xe5\xba\x86': 0,
#  '\xe9\x99\x95\xe8\xa5\xbf': 0,
#  '\xe9\x9d\x92\xe6\xb5\xb7': 0,
#  '\xe9\xa6\x99\xe6\xb8\xaf': 0,
#  '\xe9\xbb\x91\xe9\xbe\x99\xe6\xb1\x9f': 0}

# %%
def write_txt_file(path, txt):
    '''
    写入txt文本
    '''
    with open(path, 'a', encoding='gb18030', newline='') as f:
        f.write(txt)    
# 统计签名
for friend in my_friends:
    # 对数据进行清洗，将标点符号等对词频统计造成影响的因素剔除
    pattern = re.compile(r'[一-龥]+')
    filterdata = re.findall(pattern, friend.signature)
    write_txt_file('signatures.txt', ''.join(filterdata))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-82af8b38fcc6> in <module>()
#       1 # 使用一个字典统计各省好友数量
# ----> 2 province_dict = {unicode('北京'): 0, '上海': 0, '天津': 0, '重庆': 0,
#       3     '河北': 0, '山西': 0, '吉林': 0, '辽宁': 0, '黑龙江': 0,
#       4     '陕西': 0, '甘肃': 0, '青海': 0, '山东': 0, '福建': 0,
#       5     '浙江': 0, '台湾': 0, '河南': 0, '湖北': 0, '湖南': 0,
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe5 in position 0: ordinal not in range(128)

# %%
import re
filterdata= {}
for i in range(len(my_friends)):
    friend = my_friends[i]
    #pattern = re.compile(r'[一-龥]+')
    filterdata[i] = friend.signature

# %%
import numpy as np
sig = np.array([filterdata[i] for i in range(len(my_friends))])
np.savetxt('signature',sig,fmt='%s')

# %%
sig = np.array([filterdata[i].encode('utf-8') for i in range(len(my_friends))])

# %%
induse = np.where(sig !='')[0]

# %%
my_friends[induse[i]].name
# Out:
# u'\u9648\u65ed\u9e4f'

# %%
sign = np.ndarray([induse.shape[0],2]).astype('str')
for i in range(induse.shape[0]):
    sign[i,0] = str(my_friends[induse[i]].name)
    sign[i,1] = sig[induse[i]]
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-87-65603f29a386> in <module>()
#       1 sign = np.ndarray([induse.shape[0],2]).astype('str')
#       2 for i in range(induse.shape[0]):
# ----> 3     sign[i,0] = str(my_friends[induse[i]].name)
#       4     sign[i,1] = sig[induse[i]]
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 0-2: ordinal not in range(128)

# %%
np.savetxt('signature',sign,fmt='%s')#,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-68-b707a9b2dd0c> in <module>()
# ----> 1 np.savetxt('signature',sign,fmt='%s')#,encoding='utf-8')
#
# /Users/james/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1374                                     "format specifier ('%s')"
#    1375                                     % (str(X.dtype), format))
# -> 1376                 fh.write(v)
#    1377
#    1378         if len(footer) > 0:
#
# /Users/james/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in write(self, v)
#    1275
#    1276         def write(self, v):
# -> 1277             self.do_write(v)
#    1278
#    1279         def write_bytes(self, v):
#
# /Users/james/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in first_write(self, v)
#    1288         def first_write(self, v):
#    1289             try:
# -> 1290                 self.write_normal(v)
#    1291                 self.write = self.write_normal
#    1292             except TypeError:
#
# /Users/james/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in write_normal(self, v)
#    1284
#    1285         def write_normal(self, v):
# -> 1286             self.fh.write(asunicode(v))
#    1287
#    1288         def first_write(self, v):
#
# /Users/james/anaconda2/lib/python2.7/site-packages/numpy/compat/py3k.pyc in asunicode(s)
#      68         if isinstance(s, unicode):
#      69             return s
# ---> 70         return str(s).decode('ascii')
#      71
#      72     def open_latin1(filename, mode='r'):
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe9 in position 0: ordinal not in range(128)
